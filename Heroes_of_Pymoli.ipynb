# %%
#Dependencies
import pandas as pd
import numpy as np

# %%
#Save path to dataset in a variable
data_file = "../../Homework/04-Numpy-Pandas/Instructions/HeroesOfPymoli/purchase_data.json"
data_file_pd = pd.read_json(data_file, orient ="records")
data_file_pd
# Out:
#      Age                 Gender  Item ID  \
# 0     38                   Male      165
# 1     21                   Male      119
# 2     34                   Male      174
# 3     21                   Male       92
# 4     23                   Male       63
# 5     20                   Male       10
# 6     20                   Male      153
# 7     29                 Female      169
# 8     25                   Male      118
# 9     31                   Male       99
# 10    24                   Male       57
# 11    20                   Male       47
# 12    30                   Male       81
# 13    23                   Male       77
# 14    40                   Male       44
# 15    21                   Male       96
# 16    22                 Female      123
# 17    22                 Female       59
# 18    28                   Male       91
# 19    31                   Male      177
# 20    24                   Male       78
# 21    15                   Male        3
# ...

# %%
#Player Count
player_demographics = data_file_pd.loc[:, ["Gender", "SN", "Age"]]
player_demographics.head
player_demographics=player_demographics.drop_duplicates()
player_count=player_demographics.count()[0]
player_count
pd.DataFrame({"Total Players": [player_count]})
# Out:
#    Total Players
# 0            573

# %%
#Purchasing Analysis Total
number_unique_items =len(data_file_pd["Item ID"].unique())
average_purchase_price= data_file_pd["Price"].mean()
total_number_purchases= data_file_pd["Price"].count()
total_revenue=data_file_pd["Price"].sum()

# DataFrame Formatting
pd.options.display.float_format = '${:,.2f}'.format
purchasing_analysis_summary = pd.DataFrame({"Number of Unique Items":number_unique_items,
                                    "Average Purchase Price":average_purchase_price,
                                    "Number of Purchases":total_number_purchases,
                                   "Total Revenue":total_revenue},index=[0])
purchasing_analysis_summary = purchasing_analysis_summary[["Number of Unique Items","Average Purchase Price","Number of Purchases","Total Revenue"]]
print("Purchasing Analysis (Total)")
purchasing_analysis_summary
# Out:
# Purchasing Analysis (Total)
#    Number of Unique Items  Average Purchase Price  Number of Purchases  \
# 0                     183                   $2.93                  780
#
#    Total Revenue
# 0      $2,286.33

# %%
#Gender Demographics
gender_demographics_totals = player_demographics["Gender"].value_counts()
gender_demographics_percents = gender_demographics_totals / player_count * 100

gender_demographics = pd.DataFrame({"Total Count": gender_demographics_totals,
                                    "Percentage of Players": gender_demographics_percents})
pd.options.display.float_format = '{:,.2f}'.format
gender_demographics = gender_demographics.round(2)

gender_demographics
# Out:
#                        Percentage of Players  Total Count
# Male                                   81.15          465
# Female                                 17.45          100
# Other / Non-Disclosed                   1.40            8

# %%
#Purchasing Analysis Gender
gender_purchase_total = data_file_pd.groupby(["Gender"]).sum()["Price"].rename("Total Purchase Value")
gender_average = data_file_pd.groupby(["Gender"]).mean()["Price"].rename("Average Purchase Price")
gender_counts = data_file_pd.groupby(["Gender"]).count()["Price"].rename("Purchase Count")

normalized_totals = gender_purchase_total / gender_demographics["Total Count"]

gender_data = pd.DataFrame({"Normalized Total": normalized_totals, 
                            "Purchase Count": gender_counts, 
                            "Total Purchase Value": gender_purchase_total, 
                            "Average Purchase Value": gender_average})


#Display
gender_data
# Out:
#                        Average Purchase Value  Normalized Total  \
# Gender
# Female                                   2.82              3.83
# Male                                     2.95              4.02
# Other / Non-Disclosed                    3.25              4.47
#
#                        Purchase Count  Total Purchase Value
# Gender
# Female                            136                382.91
# Male                              633              1,867.68
# Other / Non-Disclosed              11                 35.74

# %%
#Age Demographics
bins = [0, 9, 14, 19, 24, 29, 34, 39, 99]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]
player_demographics["Age Group"] = pd.cut(player_demographics["Age"], bins, labels=group_names)
age_group = player_demographics.groupby("Age Group").count()
age_group = age_group[["Age"]]
age_group = age_group.rename(columns={"Age": "Total Count"})
age_group["Percentage of Players"] = age_group["Total Count"] / player_count * 100
age_group = age_group[["Percentage of Players", "Total Count"]]
pd.options.display.float_format = '{:,.2f}'.format
print("Age Demographics")
age_group
# Out:
# Age Demographics
#            Percentage of Players  Total Count
# Age Group
# <10                         3.32           19
# 10-14                       4.01           23
# 15-19                      17.45          100
# 20-24                      45.20          259
# 25-29                      15.18           87
# 30-34                       8.20           47
# 35-39                       4.71           27
# 40+                         1.92           11

# %%
# Top Spenders
user_total = data_file_pd.groupby(["SN"]).sum()["Price"].rename("Total Purchase Value")
user_average = data_file_pd.groupby(["SN"]).mean()["Price"].rename("Average Purchase Price")
user_count = data_file_pd.groupby(["SN"]).count()["Price"].rename("Purchase Count")

user_data = pd.DataFrame({"Total Purchase Value": user_total,
                          "Average Purchase Price": user_average,
                          "Purchase Count": user_count})

user_data.sort_values("Total Purchase Value", ascending=False).head(5)
# Out:
#              Average Purchase Price  Purchase Count  Total Purchase Value
# SN
# Undirrala66                    3.41               5                 17.06
# Saedue76                       3.39               4                 13.56
# Mindimnya67                    3.18               4                 12.74
# Haellysu29                     4.24               3                 12.73
# Eoda93                         3.86               3                 11.58

# %%
#Most popular items
number_unique_items = data_file_pd.groupby(["Item ID","Item Name"])

top_five_items = number_unique_items[["Price"]].count().nlargest(5,"Price")
top_five_items = top_five_items.rename(columns={"Price": "Purchase Count"})
item_prices = number_unique_items[["Price"]].mean()
item_prices = item_prices.rename(columns={"Price": "Item Price"})
merge1 = top_five_items.join(item_prices)
item_purchase_total = number_unique_items[["Price"]].sum()
item_purchase_total = item_purchase_total.rename(columns={"Price": "Total Purchase Value"})
top_five_items = merge1.join(item_purchase_total)
print("Most Popular Items")
top_five_items
# Out:
# Most Popular Items
#                                               Purchase Count  Item Price  \
# Item ID Item Name
# 39      Betrayal, Whisper of Grieving Widows              11        2.35
# 84      Arcane Gem                                        11        2.23
# 13      Serenity                                           9        1.49
# 31      Trickster                                          9        2.07
# 34      Retribution Axe                                    9        4.14
#
#                                               Total Purchase Value
# Item ID Item Name
# 39      Betrayal, Whisper of Grieving Widows                 25.85
# 84      Arcane Gem                                           24.53
# 13      Serenity                                             13.41
# 31      Trickster                                            18.63
# 34      Retribution Axe                                      37.26

# %%
#Most Profitable Items
top_five_profitable = number_unique_items[["Price"]].sum().nlargest(5,"Price")
top_five_profitable = top_five_profitable.rename(columns={"Price": "Total Purchase Value"})
top_five_profitable
item_purchases = number_unique_items[["Price"]].count()
item_purchases = item_purchases.rename(columns={"Price": "Purchase Count"})
merge1 = top_five_profitable.join(item_purchases)
item_prices = number_unique_items[["Price"]].mean()
item_prices = item_prices.rename(columns={"Price": "Item Price"})
merge2 = merge1.join(item_prices)
top_five_profitable = merge2[["Purchase Count", "Item Price", "Total Purchase Value"]]
print("Most Profitable Items")
top_five_profitable
# Out:
# Most Profitable Items
#                                     Purchase Count  Item Price  \
# Item ID Item Name
# 34      Retribution Axe                          9        4.14
# 115     Spectral Diamond Doomblade               7        4.25
# 32      Orenmir                                  6        4.95
# 103     Singed Scalpel                           6        4.87
# 107     Splitter, Foe Of Subtlety                8        3.61
#
#                                     Total Purchase Value
# Item ID Item Name
# 34      Retribution Axe                            37.26
# 115     Spectral Diamond Doomblade                 29.75
# 32      Orenmir                                    29.70
# 103     Singed Scalpel                             29.22
# 107     Splitter, Foe Of Subtlety                  28.88

# %%
# 3 observable trends based on the data
#1 The most popular item does not necesarily generate the most amount of money for the company.
#2 Men buy those games at a higher rate than Women 
#3 Young adults(20-24) are the most represented among the age groups
